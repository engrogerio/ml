# %%
import pandas as pd
import seaborn as sb

# %%
internet_df = pd.read_csv('internet.csv')
x = internet_df[['Hour', 'Users']] # independent values
y = internet_df['Speed'] # dependent values

# %%
x.describe()
y.describe()
# Out:
# count     18.000000
# mean      78.944444
# std       15.019486
# min       53.000000
# 25%       69.250000
# 50%       78.000000
# 75%       89.750000
# max      101.000000
# Name: Speed, dtype: float64

# %%
sb.scatterplot(x=x['Hour'], y=x['Users'], hue=y)
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Users'>
